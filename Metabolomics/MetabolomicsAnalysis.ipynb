# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
fcDir = 'FoldChange_ttest_GS/'
fcList = [fcDir + afile for afile in os.listdir(fcDir) if afile.startswith('FC')]
ttList = [fcDir + afile for afile in os.listdir(fcDir) if afile.startswith('ttest')]
fcList.sort()
ttList.sort()

# %%
inDict = dict(zip(fcList,ttList))
mDict={}
for afile in inDict:
    outName = afile.replace('FC','Combined_')
    species = afile.split('/')[-1].split('_')[1]
    condition = afile.split('/')[-1].split('_')[2]
    print(species,condition)
    if not species in mDict:mDict[species]={}
    #mDict[species][condition]=[]
    dffc = pd.read_csv(afile, index_col=0)
    dftt = pd.read_csv(inDict[afile], index_col=0)
    dfcombine = dffc.join(dftt)
    sigMet= list(dfcombine.loc[(np.abs(dfcombine['log2(FC)'])>=1) & (dfcombine['p.value']<=0.05)].index)
    mDict[species][condition]=sigMet
    dfcombine.to_csv(outName,sep='\t')
# Out:
# Maize Ndep
# Maize Pdep
# Pas Ndep
# Pas Pdep
# Sor Ndep
# Sor Pdep

# %%
ZmNF = mDict['Maize']['Ndep']
ZmPF = mDict['Maize']['Pdep']
SbNF = mDict['Sor']['Ndep']
SbPF = mDict['Sor']['Pdep']
PvNF = mDict['Pas']['Ndep']
PvPF = mDict['Pas']['Pdep']

# %%
from collections import Counter
NFList = ZmNF+SbNF+PvNF
PFList = ZmPF+SbPF+PvPF
nCount = Counter(NFList)
pCount = Counter(PFList)
nCount
# Out:
# Counter({'allantoin': 3,
#          'L-glutamine': 2,
#          'Beta- alanine': 2,
#          'L-asparagine': 2,
#          'gamma-aminobutyric acid (GABA)': 2,
#          'caffeic acid': 2,
#          'L-threonine': 2,
#          'capric acid': 2,
#          'threonic acid': 2,
#          'aspartic acid': 2,
#          'beta-cyano-L-alanine': 2,
#          'L-valine': 2,
#          'L-serine': 2,
#          'myristic acid': 1,
#          '1,3-diaminopropane': 3,
#          'glycerol 1-phosphate': 1,
#          'L-homoserine': 1,
#          'maleic acid': 3,
#          'succinic acid': 3,
#          'L-Isoleucine': 1,
#          'L-leucine': 1,
#          'Antiarol': 2,
#          '3,5-dimethoxy-4-hydroxycinnamic acid': 2,
#          'L-glutamic acid': 1,
#          'adenosine': 1,
#          'elaidic acid': 1,
#          'citric acid': 1,
#          '5,6-dihydrouracil': 1,
#          'shikimic acid': 1,
#          'L-proline': 1,
#          'itaconic acid': 1,
#          'spermidine': 1,
#          'xylose': 1,
#          'glyceric acid': 1,
#          'Trehalose': 1,
#          'L-lysine': 1,
#          'beta-gentiobiose': 1})

# %%
NF1 = [x for x in nCount if nCount[x]==1]
PF1 = [x for x in pCount if pCount[x]==1]
ZmNF1 = [x for x in ZmNF if x in NF1]
SbNF1 = [x for x in SbNF if x in NF1]
ZmPF1 = [x for x in ZmPF if x in PF1]
SbPF1 = [x for x in SbPF if x in PF1]

# %%
dfZmNF1 = pd.read_csv('FoldChange_ttest_GS/Combined__Maize_Ndep_VS_FN.csv',sep='\t',index_col=0)
dfSbNF1 = pd.read_csv('FoldChange_ttest_GS/Combined__Sor_Ndep_VS_FN.csv', sep='\t',index_col=0)

# %%
dfZmPF1 = pd.read_csv('FoldChange_ttest_GS/Combined__Maize_Pdep_VS_FN.csv',sep='\t',index_col=0)
dfSbPF1 = pd.read_csv('FoldChange_ttest_GS/Combined__Sor_Pdep_VS_FN.csv', sep='\t',index_col=0)

# %%
SbZmPF2 = [x for x in ZmPF if x in SbPF]

# %%
dfZmPF1.loc[SbZmPF2]
# Out:
#                        FoldChange  log2(FC)       p.value    -log10       fdr
# L-glutamine              0.115679 -3.111807  3.389017e-03  2.469926  0.011992
# capric acid              0.217309 -2.202182  4.310223e-03  2.365500  0.014162
# D-glucose-6-phosphate    0.231200 -2.112785  1.974586e-04  3.704524  0.001397
# L-asparagine             0.327816 -1.609042  1.358234e-03  2.867025  0.005950
# beta-cyano-L-alanine     0.344945 -1.535560  3.584009e-03  2.445631  0.012212
# glycerol 1-phosphate     2.097624  1.068756  5.139244e-07  6.289101  0.000016

# %%
dfSbPF1.loc[SbZmPF2]
# Out:
#                        FoldChange  log2(FC)   p.value    -log10       fdr
# L-glutamine              0.357245 -1.485015  0.000455  3.342319  0.003218
# capric acid              0.401734 -1.315687  0.000039  4.413658  0.000535
# D-glucose-6-phosphate    0.208798 -2.259823  0.000024  4.627580  0.000535
# L-asparagine             0.240800 -2.054093  0.000040  4.400293  0.000535
# beta-cyano-L-alanine     0.227286 -2.137422  0.000135  3.868288  0.001557
# glycerol 1-phosphate     0.481941 -1.053071  0.000222  3.654517  0.002265

# %%
SbZmNF = [x for x in ZmNF if x in SbNF]
SbZmNF
# Out:
# ['allantoin',
#  'L-glutamine',
#  'Beta- alanine',
#  'L-asparagine',
#  'gamma-aminobutyric acid (GABA)',
#  'caffeic acid',
#  'L-threonine',
#  'capric acid',
#  'threonic acid',
#  'aspartic acid',
#  'beta-cyano-L-alanine',
#  'L-valine',
#  'L-serine',
#  '1,3-diaminopropane',
#  'maleic acid',
#  'succinic acid',
#  'Antiarol',
#  '3,5-dimethoxy-4-hydroxycinnamic acid']

# %%
import sys
sys.path.append(r'/home/gsun2unl/Documents/Nutrient_stress/DATA2019/DESeq2/venn')
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline
import venn

# %%
fig,ax = plt.subplots(figsize=(8,8))
ax = venn3([set(ZmNF), set(SbNF), set(PvNF)],('Maize(-N)', 'Sorghum(-N)','Paspalum(-N)'))

# %%
ax = venn3([set(ZmPF), set(SbPF), set(PvPF)],('Maize(-P)', 'Sorghum(-P)','Paspalum(-P)'))

# %%
labels = venn.get_labels([set(ZmNF), set(SbNF), set(PvNF)],fill=['number'],)
venn3(labels,names=('Maize(-N)', 'Sorghum(-N)','Paspalum(-N)'))
plt.title('Comparison of Nitrogen starvation responsive primary metabolites')
plt.savefig('Comparison_NF.svg')

# %%
labels = venn.get_labels([set(ZmPF), set(SbPF), set(PvPF)],)#fill=['number'],)
venn.venn3(labels,names=('Maize(-P)', 'Sorghum(-P)','Paspalum(-P)'))
plt.title('Comparison of Phosphorus starvation responsive primary metabolites')
plt.savefig('Comparison_PF.svg')

# %%
dfclean = pd.read_csv('2_Cleaned_normalized_Area_92_metabolites.csv',)
dfclean
# Out:
#        Sample       Rawname Condition  FW_mg  Rep          Species Treatment  \
# 0   Sor_Ndep1  181221_012.D  Sor_Ndep   54.0    1  Sorghum bicolor     N_dep
# 1   Sor_Ndep2  181221_013.D  Sor_Ndep   50.0    2  Sorghum bicolor     N_dep
# 2   Sor_Ndep3  181221_014.D  Sor_Ndep   50.0    3  Sorghum bicolor     N_dep
# 3   Sor_Ndep4  181221_015.D  Sor_Ndep   48.0    4  Sorghum bicolor     N_dep
# 4   Sor_Ndep5  181221_016.D  Sor_Ndep   45.0    5  Sorghum bicolor     N_dep
# ..        ...           ...       ...    ...  ...              ...       ...
# 85    Set_FN1  181221_107.D    Set_FN   54.3    1  Setaria italica        FN
# 86    Set_FN2  181221_108.D    Set_FN   55.7    2  Setaria italica        FN
# 87    Set_FN3  181221_109.D    Set_FN   58.3    3  Setaria italica        FN
# 88    Set_FN4  181221_110.D    Set_FN   52.0    4  Setaria italica        FN
# 89    Set_FN5  181221_111.D    Set_FN   56.3    5  Setaria italica        FN
#
#     2-hydroxypyridine   Pyruvic acid   L-alanine  ...  serotonin  arbutin   \
# 0             0.251576       0.015336   0.019508  ...   0.001018  0.539128
# 1             0.211654       0.016744   0.020659  ...   0.000427  2.050000
# 2             0.181786       0.012575   0.022132  ...   0.001111  0.390556
# 3             0.146656       0.011642   0.019273  ...   0.000751  2.457424
# 4             0.202752       0.013738   0.017724  ...   0.000484  1.670713
# ..                 ...            ...        ...  ...        ...       ...
# 85            0.325835       0.030931   0.037067  ...   0.111039  8.067196
# 86            0.315706       0.028807   0.033302  ...   0.140459  7.856736
# 87            0.368014       0.037734   0.041083  ...   0.199669  9.099527
# 88            0.174332       0.012777   0.026211  ...   0.004806  1.927206
# 89            0.341188       0.031686   0.036332  ...   0.120479  9.044500
#
#     eicosapentaenoic acid   adenosine   Sucrose    lactose   maltose  \
# 0                 0.416886    0.094001  2.736975  1.906343  1.762930
# 1                 1.805599    0.102193  2.507112  1.809645  1.828206
# 2                 1.488130    0.123629  2.964215  1.961747  2.647713
# 3                 1.146022    0.115736  3.045384  1.901175  2.381452
# 4                 1.663821    0.074278  2.268546  1.668527  1.533161
# ..                     ...         ...       ...       ...       ...
# 85                4.612115    0.013011  3.730590  4.608183  0.961839
# 86                4.779696    0.014190  3.637011  4.782158  0.746038
# 87                5.262508    0.015590  4.246544  5.300499  0.862221
# 88                1.878760    0.009015  2.670573  1.763724  1.097393
# 89                5.120296    0.013112  4.118640  3.860210  0.904374
#
#     Trehalose   beta-gentiobiose  galactinol
# 0     1.140207          1.103512    0.265116
# 1     1.138503          1.109200    0.232000
# 2     1.792052          1.792205    0.708405
# 3     1.853418          1.861384    0.704551
# 4     0.917974          0.939391    0.185231
# ..         ...               ...         ...
# 85    0.106675          0.105671    0.082620
# 86    0.149041          0.149004    0.087870
# 87    0.141138          0.141095    0.108346
# 88    0.156089          0.156073    0.348723
# 89    0.173530          0.175764    0.086232
#
# [90 rows x 99 columns]

# %%
newcol = [x.strip() for x in list(dfclean)]
dfclean.columns = newcol

# %%
import numpy as np
tList=np.tile(np.repeat(['-N','-P','Full'],5),3)
tList
# Out:
# array(['-N', '-N', '-N', '-N', '-N', '-P', '-P', '-P', '-P', '-P', 'Full',
#        'Full', 'Full', 'Full', 'Full', '-N', '-N', '-N', '-N', '-N', '-P',
#        '-P', '-P', '-P', '-P', 'Full', 'Full', 'Full', 'Full', 'Full',
#        '-N', '-N', '-N', '-N', '-N', '-P', '-P', '-P', '-P', '-P', 'Full',
#        'Full', 'Full', 'Full', 'Full'], dtype='<U4')

# %%
SelCol = ['Treatment']+seList
dfsub = dfclean.set_index('Species').loc[['Sorghum bicolor','Zea mays B73','Paspalum vaginatum']][SelCol]
dfsub.reset_index(inplace=True)
dfsub['Treatment']=list(tList)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2b084e3f989e> in <module>
# ----> 1 SelCol = ['Treatment']+seList
#       2 dfsub = dfclean.set_index('Species').loc[['Sorghum bicolor','Zea mays B73','Paspalum vaginatum']][SelCol]
#       3 dfsub.reset_index(inplace=True)
#       4 dfsub['Treatment']=list(tList)
#
# NameError: name 'seList' is not defined

# %%
dfsub.to_csv('Boxplot_use.csv',index=False,sep='\t')

# %%
subList = ['Species', 'Treatment','allantoin','gamma-aminobutyric acid (GABA)','caffeic acid','maleic acid','succinic acid','Trehalose']
dfsubSub = dfsub[subList]

# %%
dfsub.set_index('Species').loc['Paspalum vaginatum'].boxplot(by = 'Treatment',figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a262c518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a26d59e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a26082b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2600278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a256d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a250a6d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a252a9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a24d2cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a24d2cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a24af278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2456550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a247d828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2425b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a23d0dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a23830f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a23ab3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a23526a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a237a978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2324c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a22cdf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a22fe240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a22a6518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a22507f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2279ac8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2222da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a21d40b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a21fc390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a21a4668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a214f940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2176c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a211fef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a20d3208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a20f94e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a20a27b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a204ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2074d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a2027080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a1fce358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a1ff6630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a1f9f908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a1f48be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa4a1f7b198>]],
#       dtype=object)

# %%
dfSub = pd.read_csv('Boxplot_use.csv',sep='\t')
dfSub
# Out:
#                Species Treatment  1,3-diaminopropane  L-serine  glyceric acid  \
# 0      Sorghum bicolor        -N            0.015378  0.639556       0.012265
# 1      Sorghum bicolor        -N            0.016615  0.702190       0.010041
# 2      Sorghum bicolor        -N            0.017965  1.057744       0.010935
# 3      Sorghum bicolor        -N            0.016111  0.397969       0.011183
# 4      Sorghum bicolor        -N            0.014339  0.567209       0.009708
# 5      Sorghum bicolor        -P            0.023101  1.376099       0.012216
# 6      Sorghum bicolor        -P            0.024647  1.118988       0.010533
# 7      Sorghum bicolor        -P            0.014111  1.036229       0.009747
# 8      Sorghum bicolor        -P            0.021571  1.171469       0.010135
# 9      Sorghum bicolor        -P            0.018824  0.664527       0.011092
# 10     Sorghum bicolor      Full            0.043305  1.735840       0.014043
# 11     Sorghum bicolor      Full            0.039222  2.040763       0.018109
# 12     Sorghum bicolor      Full            0.029237  1.671544       0.012192
# 13     Sorghum bicolor      Full            0.046999  2.022381       0.013835
# 14     Sorghum bicolor      Full            0.051463  1.699278       0.014223
# 15        Zea mays B73        -N            0.014520  0.191676       0.015740
# 16        Zea mays B73        -N            0.011814  0.482935       0.013386
# 17        Zea mays B73        -N            0.009954  0.166657       0.009970
# 18        Zea mays B73        -N            0.008473  0.341680       0.009705
# 19        Zea mays B73        -N            0.014916  1.158181       0.017635
# 20        Zea mays B73        -P            0.014422  1.126744       0.010666
# 21        Zea mays B73        -P            0.017852  1.215232       0.013200
# 22        Zea mays B73        -P            0.015396  1.076408       0.011235
# 23        Zea mays B73        -P            0.014945  0.897095       0.011976
# 24        Zea mays B73        -P            0.021129  0.957311       0.014192
# 25        Zea mays B73      Full            0.036880  1.264394       0.024216
# 26        Zea mays B73      Full            0.027455  1.974668       0.017512
# 27        Zea mays B73      Full            0.031123  1.561680       0.017254
# 28        Zea mays B73      Full            0.034344  1.170010       0.022325
# 29        Zea mays B73      Full            0.034798  1.923917       0.023439
# 30  Paspalum vaginatum        -N            0.006968  0.434157       0.021076
# 31  Paspalum vaginatum        -N            0.004819  0.768592       0.019011
# 32  Paspalum vaginatum        -N            0.006387  0.849694       0.019688
# 33  Paspalum vaginatum        -N            0.006461  0.797538       0.021136
# 34  Paspalum vaginatum        -N            0.004010  0.759091       0.017395
# 35  Paspalum vaginatum        -P            0.019408  0.156575       0.018204
# 36  Paspalum vaginatum        -P            0.023147  1.077902       0.019423
# 37  Paspalum vaginatum        -P            0.022412  0.113032       0.018599
# 38  Paspalum vaginatum        -P            0.020248  1.072106       0.016554
# 39  Paspalum vaginatum        -P            0.008334  0.758270       0.018542
# 40  Paspalum vaginatum      Full            0.014332  1.165108       0.073368
# 41  Paspalum vaginatum      Full            0.016888  0.106731       0.148001
# 42  Paspalum vaginatum      Full            0.014912  1.303089       0.112096
# 43  Paspalum vaginatum      Full            0.015457  1.144856       0.080095
# 44  Paspalum vaginatum      Full            0.004851  0.460557       0.010392
#
#     elaidic acid  L-glutamic acid  serotonin  beta-cyano-L-alanine  \
# 0       0.011766         0.677086   0.001018              0.064214
# 1       0.009431         0.884707   0.000427              0.061398
# 2       0.008456         1.059736   0.001111              0.106191
# 3       0.007105         0.965452   0.000751              0.061475
# 4       0.006161         0.697514   0.000484              0.074314
# 5       0.005083         1.520343   0.003758              0.154231
# 6       0.004788         1.389584   0.003182              0.129969
# 7       0.004579         1.257205   0.012531              0.108494
# 11       1.916932       0.005918       0.043080      0.014728     1.552192
# 12       1.705998       0.006878       0.038658      0.014706     1.228183
# 13       1.921880       0.013486       0.051056      0.012319     1.560682
# 14       1.636080       0.008841       0.055850      0.011866     1.410877
# 15       0.464677       0.021292       0.018344      0.252585     0.108762
# 16       0.365692       0.018220       0.017627      0.170671     0.251257
# 17       0.314304       0.016391       0.014102      0.143293     0.094642
# 18       0.238487       0.013245       0.014712      0.273299     0.184732
# 19       0.842737       0.023838       0.021052      0.427466     0.829401
# 20       1.327237       0.005136       0.049235      0.121776     0.929308
# 21       1.297413       0.004499       0.057487      0.061884     0.756677
# 22       1.253773       0.003902       0.049393      0.052852     0.791902
# 23       1.145257       0.004798       0.055036      0.041173     0.599527
# 24       1.214153       0.004290       0.053378      0.039512     0.677562
# 25       1.877736       0.008490       0.089624      0.093479     1.109469
# 26       2.017089       0.005800       0.062512      0.041046     1.618214
# 27       1.754781       0.007916       0.073306      0.036240     1.425512
# 28       1.789043       0.008364       0.079904      0.035981     1.002750
# 29       2.052208       0.007878       0.075869      0.054816     1.594893
# 30       1.050183       0.028713       0.027937      1.459359     0.233489
# 31       1.028612       0.024987       0.028016      1.592630     0.440823
# 32       1.102383       0.023229       0.027545      1.736914     0.482711
# 33       1.097639       0.023969       0.030748      1.930780     0.443859
# 34       1.032259       0.021792       0.026169      1.732791     0.415382
# 35       1.492539       0.006454       0.038765      1.729022     0.083486
# 36       1.663206       0.006270       0.043073      1.889227     0.688336
# 37       1.527986       0.006361       0.041585      1.778223     0.060282
# 38       1.660072       0.006228       0.040035      1.686994     0.639199
# 39       1.959401       0.010246       0.043119      1.928121     0.413161
# 40       1.773496       0.009082       0.045852      1.772875     0.668094
# 41       1.628553       0.013871       0.088060      1.895220     0.058972
# 42       2.237821       0.008280       0.063690      1.870640     0.695047
# 43       1.947229       0.007862       0.052298      1.694423     0.630159
# 44       1.269934       0.006544       0.021063      1.519774     0.256179
#
# [45 rows x 42 columns]

# %%
subList = ['Species','Treatment','gamma-aminobutyric acid (GABA)','succinic acid','maleic acid','allantoin','Trehalose']
dfsubSub = dfSub[subList]

# %%
import seaborn as sns
import matplotlib as mpl
fig,axes = plt.subplots(1,3, figsize=(30,8))
mpl.rcParams['axes.linewidth'] = 3
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['xtick.minor.size'] = 10
mpl.rcParams['xtick.minor.width'] = 2
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.major.width'] = 2
mpl.rcParams['ytick.minor.size'] = 10
mpl.rcParams['ytick.minor.width'] = 2
mpl.rcParams['ytick.labelsize'] = 18
mpl.rcParams['font.family']=['sans-serif']
for a,b in enumerate(subList[2:5]):
    row = divmod(int(a),3)[1]
    print(row)
    #col = divmod(int(a),3)[1]
    #print(row,col)
    #ax = axes[row,col]
    ax = axes[row]
    sns.boxplot(x='Species',y=b, hue='Treatment', hue_order=['Full','-N','-P'] ,data=dfsubSub,fliersize=0,ax=ax,linewidth=3)
    sns.stripplot(x='Species',y=b, hue='Treatment',hue_order=['Full','-N','-P'],data=dfsubSub, jitter=True,split=True,linewidth=2,edgecolor='gray',ax=ax)
    ax.axvline(0.5,color='black',linestyle= '--', linewidth=2)
    ax.axvline(1.5,color='black',linestyle= '--', linewidth=2)
    ax.set_xticklabels(['Maize','Sorghum','Paspalum'],size=16,fontweight='bold')
    ax.set_title(b,fontsize=20,fontweight='bold')
    ax.set_ylabel('Metabolite levels',size=20, color='black',fontweight='bold')
    ax.set_xlabel('')
    handles, labels = ax.get_legend_handles_labels()
    l = ax.legend(handles[:3], labels[:3])
plt.savefig('DE_Met.svg')
# Out:
# 0
# /home/gsun2unl/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# /home/gsun2unl/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1
# 2
# /home/gsun2unl/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib as mpl
fig,axes = plt.subplots(1,2, figsize=(20,8))
subList = ['Species','Treatment','allantoin','Trehalose']
mpl.rcParams['axes.linewidth'] = 3
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.major.width'] = 2
mpl.rcParams['xtick.minor.size'] = 10
mpl.rcParams['xtick.minor.width'] = 2
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.major.width'] = 2
mpl.rcParams['ytick.minor.size'] = 10
mpl.rcParams['ytick.minor.width'] = 2
mpl.rcParams['ytick.labelsize'] = 18
mpl.rcParams['font.family']=['sans-serif']
for a,b in enumerate(subList[2:]):
    row = divmod(int(a),2)[1]
    print(row)
    #col = divmod(int(a),3)[1]
    #print(row,col)
    #ax = axes[row,col]
    ax = axes[row]
    sns.boxplot(x='Species',y=b, hue='Treatment', hue_order=['Full','-N','-P'] ,data=dfsubSub,fliersize=0,ax=ax,linewidth=3)
    sns.stripplot(x='Species',y=b, hue='Treatment',hue_order=['Full','-N','-P'],data=dfsubSub, jitter=True,split=True,linewidth=2,edgecolor='gray',ax=ax)
    ax.axvline(0.5,color='black',linestyle= '--', linewidth=2)
    ax.axvline(1.5,color='black',linestyle= '--', linewidth=2)
    ax.set_xticklabels(['Maize','Sorghum','Paspalum'],size=16,fontweight='bold')
    ax.set_title(b,fontsize=20,fontweight='bold')
    ax.set_ylabel('Metabolite levels',size=20, color='black',fontweight='bold')
    ax.set_xlabel('')
    handles, labels = ax.get_legend_handles_labels()
    l = ax.legend(handles[:3], labels[:3])
plt.savefig('DE_Met_Alla_Tre.svg')
# Out:
# 0
# /home/gsun2unl/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# 1
# /home/gsun2unl/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
